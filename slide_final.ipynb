# %% [markdown]
# # Bay Wheels Bike Sharing System Usage Pattern
# ## by Adrian Alvizuri

# %% [markdown]
# ## Investigation Overview
#
# > Bay Wheels (previously known as Ford GoBike) is a regional public bike sharing system in the San Francisco Bay Area, California. Bay Wheels is the first regional and large-scale bicycle sharing system deployed in California and on the West Coast of the United States with nearly 500,000 rides since the launch in 2017 and had about 10,000 annual subscribers as of January 2018. The dataset used for this exploratory analysis consists of [monthly individual trip data](https://www.lyft.com/bikes/bay-wheels/system-data) from January 2018 to December 2018 in CSV format covering the greater San Francisco Bay area
# ## Dataset Overview
#
# > The original combined data contains approximately 1,860,000 individual trip records with 16 variables collected. The variables can be divided into 3 major categories:trip duration, station information and support variables which where added to help the analysis.
# The following features will help to support my investigation: trip's start date/time and duration information and demographics like user type, gender and age.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import os
import glob

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df_bt_18 = pd.read_csv('fordgobike_trips_2018_II.csv')

# %% [markdown]
# ## User types
#
# > Subscribers takes more rides than costumers (89% vs 11%).

# %%
plt.figure(figsize=[16, 6]);
base_color = sb.color_palette('colorblind')[0];
sb.set_style('darkgrid');

plt.subplot(1, 2, 1);
sorted_vals = df_bt_18.user_type.value_counts()/df_bt_18.shape[0];
plt.pie(sorted_vals, explode=[0, 0.1], labels=sorted_vals.index, startangle=90, counterclock=False, autopct='%1.1f%%', shadow=True);
plt.axis('square');
plt.title('User types')
# Out:
# Text(0.5, 1.0, 'User types')

# %% [markdown]
# ## Monthly usage
#
# > Both user types tend to ride more during the summer.

# %%
plt.figure(figsize=[16, 6]);
base_color = sb.color_palette('colorblind')[0];
sb.set_style('darkgrid');

plt.subplot(1, 2, 2);
ax = sb.countplot(data=df_bt_18, x='start_month', hue='user_type', hue_order=sorted_vals.index);
ax.legend(title='User Type');
plt.xticks(rotation=30);
plt.xlabel('');
plt.ylabel('Count');
plt.title('User Types and Their Monthly Usage', fontsize=14, fontweight='semibold', y=1.015);

# %% [markdown]
# ## Customers and Subscribers Weekday Trip Duration
#
# > In general, we can see that subscribers take shorter trips than customers.The trips taken by customers and subs increase on weekends.

# %%
weekday = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekdaycat = pd.api.types.CategoricalDtype(ordered=True, categories=weekday)
df_bt_18['start_dayofweek'] = df_bt_18['start_dayofweek'].astype(weekdaycat)

sb.pointplot(data=df_bt_18, x='start_dayofweek', y='duration_min', hue='user_type', dodge=0.3, linestyles="");
plt.xlabel('Day of Week');
plt.ylabel('Avg. Trip Duration in Minute')
plt.title('Customers and Subscribers Weekday Trip Duration ');

# %%
from socket import *
s = socket(AF_INET, SOCK_STREAM)
s.setsockopt(SOL_SOCKET, SO_REUSEADDR, 1)

# %%
# !jupyter nbconvert slide_final.ipynb --to slides --post serve --template output_toggle
# Out:
# [NbConvertApp] Converting notebook slide_final.ipynb to slides
# [NbConvertApp] Writing 378548 bytes to slide_final.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Traceback (most recent call last):
#   File "C:\Users\adria\anaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\adria\anaconda3\lib\site-packages\jupyter_core\application.py", line 268, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "C:\Users\adria\anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\adria\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 340, in start
#     self.convert_notebooks()
#   File "C:\Users\adria\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 510, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "C:\Users\adria\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 483, in convert_single_notebook
#     self.postprocess_single_notebook(write_results)
#   File "C:\Users\adria\anaconda3\lib\site-packages\nbconvert\nbconvertapp.py", line 455, in postprocess_single_notebook
#     self.postprocessor(write_results)
#   File "C:\Users\adria\anaconda3\lib\site-packages\nbconvert\postprocessors\base.py", line 28, in __call__
#     self.postprocess(input)
#   File "C:\Users\adria\anaconda3\lib\site-packages\nbconvert\postprocessors\serve.py", line 90, in postprocess
#     http_server.listen(self.port, address=self.ip)
#   File "C:\Users\adria\anaconda3\lib\site-packages\tornado\tcpserver.py", line 151, in listen
#     sockets = bind_sockets(port, address=address)
#   File "C:\Users\adria\anaconda3\lib\site-packages\tornado\netutil.py", line 174, in bind_sockets
#     sock.bind(sockaddr)
# OSError: [WinError 10048] Solo se permite un uso de cada dirección de socket (protocolo/dirección de red/puerto)

# %%
from notebook import notebookapp
port_list = [note["port"] for note in notebookapp.list_running_servers()]
port_list
# Out:
# [8888, 8888, 8888, 8889, 8888, 8890, 8888, 8888]
